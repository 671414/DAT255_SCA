# %%
import src.DAT255_SCA.utils.dataset_utils as dutils

# %%
file_path = "../datasets/training_set.hdf5"
dutils.create_dataset(file_path, 256, 256, "training")
#restart kernel for file to show up

# %%
# %cd "../datasets/"
# %ls
# Out:
# /Users/kaspar/PycharmProjects/DAT255_SCA_ny/notebooks/datasets
# attack/            test/              train/
# attack_set.hdf5    testing_set.hdf5   training_set.hdf5

# %%
file_path = "../datasets/train/training_0.hdf5"
dutils.new_inspect(file_path)
# Out:
# training_0
# traces
# <HDF5 dataset "traces": shape (256, 5000, 1), type "<f4">
# (256, 5000, 1) float32
# (256, 5000, 1) float32
# [[[-0.2156862 ]
#   [ 0.28627455]
#   [-0.02745092]
#   ...
#   [ 0.23921573]
#   [ 0.19215691]
#   [-0.0666666 ]]
#
#  [[-0.18431365]
#   [ 0.30196083]
#   [-0.02745092]
#   ...
#   [ 0.21568632]
#   [ 0.19215691]
#   [-0.08235288]]
#
#  [[-0.19999993]
#   [ 0.30196083]
#   [-0.04313719]
#   ...
#   [ 0.2313726 ]
#   [ 0.20000005]
#   [-0.04313719]]
#
#  ...
#
#  [[-0.18431365]
#   [ 0.27058828]
#   [-0.04313719]
#   ...
#   [ 0.20784318]
#   [ 0.17647064]
#   [-0.07450974]]
#
#  [[-0.19999993]
#   [ 0.28627455]
#   [-0.04313719]
#   ...
#   [ 0.20000005]
#   [ 0.16078436]
#   [-0.07450974]]
#
#  [[-0.17647052]
#   [ 0.30196083]
#   [-0.03529406]
#   ...
#   [ 0.22352946]
#   [ 0.19215691]
#   [-0.0666666 ]]]
# key
# <HDF5 dataset "key": shape (16, 256), type "|u1">
# (16, 256) uint8
# (16, 256) uint8
# [[ 43  43  43 ...  43  43  43]
# ...

# %%
file_path = "../datasets/training_set.hdf5"

dutils.close_file(file_path)
